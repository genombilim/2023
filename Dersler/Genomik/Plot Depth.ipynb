# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('depth.csv', sep='\t', names=["Chr", "Position", "Depth"])
dataset
# Out:
#         Chr  Position  Depth
# 0      chrM         1    639
# 1      chrM         2   1210
# 2      chrM         3   1484
# 3      chrM         4   1513
# 4      chrM         5   1515
# ...     ...       ...    ...
# 16564  chrM     16565   1974
# 16565  chrM     16566   1671
# 16566  chrM     16567   1480
# 16567  chrM     16568   1273
# 16568  chrM     16569    746
#
# [16569 rows x 3 columns]

# %%
dataset.plot.scatter(x = 'Position', y = 'Depth')
# Out:
# <Axes: xlabel='Position', ylabel='Depth'>

# %%
dataset.Depth.min()
# Out:
# 209
